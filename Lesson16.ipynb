# %%
import pandas as pd
import pylab as pl
import numpy as np
# %pylab inline
cols = ['area','perimeter','compactness','length','width','asymmetry','grove','?']
seeds = pd.read_csv('./Downloads/seeds.csv', header=None,names=cols,index_col=None)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = seeds.asymmetry.values
y = seeds.grove.values
pl.scatter(x,y,s=100)

# %%
print km.inertia_
# Out:
# 21.5738242102

# %%
from sklearn.cluster import KMeans 
X = array([x,y]).T
km = KMeans(n_clusters=15, n_init=1000)
km.fit(X)
pl.scatter(X[:,0],X[:,1], c= km.labels_, s=100)

# %%
print km.inertia_
# Out:
# 17.8917529888

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.cluster import KMeans 
X = array([x,y]).T
km = KMeans(n_clusters=15, n_init=10000)
km.fit(X)
pl.scatter(X[:,0],X[:,1], c= km.labels_, s=100)

# %%
print km.inertia_
# Out:
# 17.8882682098

# %%
Y = MinMaxScaler().fit_transform(X)
Y
# Out:
# array([[ 0.18930164,  0.34515017],
#        [ 0.03288302,  0.21516494],
#        [ 0.25145302,  0.1506647 ],
#        [ 0.19424255,  0.14081733],
#        [ 0.07670104,  0.3229936 ],
#        [ 0.22063738,  0.21516494],
#        [ 0.36678412,  0.3446578 ],
#        [ 0.25158304,  0.23682915],
#        [ 0.16576734,  0.66863614],
#        [ 0.15653565,  0.49926145],
#        [ 0.49121689,  0.39143279],
#        [ 0.12376965,  0.23732152],
#        [ 0.41879364,  0.10782866],
#        [ 0.30827341,  0.17380601],
#        [ 0.28174856,  0.1506647 ],
#        [ 0.44466837,  0.12900049],
#        [ 0.58106333,  0.12900049],
#        [ 0.10842684,  0.25947809],
#        [ 0.13027084,  0.06400788],
#        [ 0.4338764 ,  0.19448548],
#        [ 0.29995189,  0.32348597],
#        [ 0.25002275,  0.3446578 ],
#        [ 0.        ,  0.28163466],
#        [ 0.08450246,  0.21762678],
#        [ 0.13339141,  0.23732152],
#        [ 0.01793028,  0.38798621],
#        [ 0.33908905,  0.1506647 ],
# ...

# %%
X
# Out:
# array([[ 2.221 ,  5.22  ],
#        [ 1.018 ,  4.956 ],
#        [ 2.699 ,  4.825 ],
#        [ 2.259 ,  4.805 ],
#        [ 1.355 ,  5.175 ],
#        [ 2.462 ,  4.956 ],
#        [ 3.586 ,  5.219 ],
#        [ 2.7   ,  5.    ],
#        [ 2.04  ,  5.877 ],
#        [ 1.969 ,  5.533 ],
#        [ 4.543 ,  5.314 ],
#        [ 1.717 ,  5.001 ],
#        [ 3.986 ,  4.738 ],
#        [ 3.136 ,  4.872 ],
#        [ 2.932 ,  4.825 ],
#        [ 4.185 ,  4.781 ],
#        [ 5.234 ,  4.781 ],
#        [ 1.599 ,  5.046 ],
#        [ 1.767 ,  4.649 ],
#        [ 4.102 ,  4.914 ],
#        [ 3.072 ,  5.176 ],
#        [ 2.688 ,  5.219 ],
#        [ 0.7651,  5.091 ],
#        [ 1.415 ,  4.961 ],
#        [ 1.791 ,  5.001 ],
#        [ 0.903 ,  5.307 ],
#        [ 3.373 ,  4.825 ],
#        [ 2.504 ,  4.869 ],
#        [ 2.754 ,  5.038 ],
#        [ 3.531 ,  5.097 ],
#        [ 0.8551,  5.056 ],
#        [ 3.412 ,  5.228 ],
#        [ 3.92  ,  5.299 ],
#        [ 2.124 ,  5.012 ],
# ...

# %%
from sklearn.cluster import KMeans 
km = KMeans(n_clusters=2, n_init=1000)
km.fit(Y)
pl.scatter(Y[:,0],Y[:,1], c= km.labels_, s=100)

# %%
print km.inertia_
# Out:
# 10.279566141
