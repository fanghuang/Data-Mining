# %%
import pandas as pd
import matplotlib.pyplot as plt
crime = pd.read_csv('Crimes_-_2001_to_present.csv')
crime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5351512 entries, 0 to 5351511
# Columns: 22 entries, ID to Location
# dtypes: bool(2), float64(5), int64(3), object(12)

# %%
crime.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 22 columns):
# ID                      5  non-null values
# Case Number             5  non-null values
# Date                    5  non-null values
# Block                   5  non-null values
# IUCR                    5  non-null values
# Primary Type            5  non-null values
# Description             5  non-null values
# Location Description    5  non-null values
# Arrest                  5  non-null values
# Domestic                5  non-null values
# Beat                    5  non-null values
# District                5  non-null values
# Ward                    5  non-null values
# Community Area          5  non-null values
# FBI Code                5  non-null values
# X Coordinate            5  non-null values
# Y Coordinate            5  non-null values
# Year                    5  non-null values
# Updated On              5  non-null values
# ...

# %%
a=crime['Location']
a
# Out:
# 0      (41.71073565878992, -87.61005767548221)
# 1       (41.90375343440057, -87.6338361913055)
# 2       (41.941306952830075, -87.658864710738)
# 3      (41.75789483238409, -87.55639899935373)
# 4      (41.90586521285494, -87.67063328653585)
# 5     (41.871741048201116, -87.70790763554812)
# 6     (41.912584873863466, -87.66337385676397)
# 7                                          NaN
# 8                                          NaN
# 9      (41.98073355854053, -87.80574022026211)
# 10     (41.85306383058161, -87.71351101968641)
# 11     (41.65448803505627, -87.60575099180764)
# 12     (41.87619792918871, -87.73262361142675)
# 13                                         NaN
# 14      (41.90976245680162, -87.7273420545432)
# ...
# 5351497      (41.92027729022528, -87.7558918674036)
# 5351498     (41.96032758384995, -87.65615298049447)
# 5351499    (41.678886682641945, -87.61866545556123)
# 5351500      (41.8054495395282, -87.65409291269344)
# ...

# %%
crime['Latitude']
crime['Latitude']
# Out:
# 0     41.710736
# 1     41.903753
# 2     41.941307
# 3     41.757895
# 4     41.905865
# 5     41.871741
# 6     41.912585
# 7           NaN
# 8           NaN
# 9     41.980734
# 10    41.853064
# 11    41.654488
# 12    41.876198
# 13          NaN
# 14    41.909762
# ...
# 5351497    41.920277
# 5351498    41.960328
# 5351499    41.678887
# 5351500    41.805450
# 5351501    41.861443
# 5351502    41.878582
# 5351503    41.919153
# 5351504    41.899291
# 5351505    41.911843
# 5351506    41.886272
# 5351507    41.664388
# 5351508    41.924526
# 5351509    41.937933
# 5351510    41.900473
# 5351511    41.844978
# Name: Latitude, Length: 5351512, dtype: float64

# %%
H5 Due Fri 12-20-13 

Entrance Survey

Entrance Survey Feedback

Blog Site for Homework 4

Chicago City plt.plot(crime['Longitude'],crime['Latitude'],'ro')
#plt.axis([40, 50, -90, -85])

# %%
hexbin(crime['Longitude'],crime['Latitude'],bins='log')
cb = plt.colorbar()
cb.set_label('log10(N)')

# %%
hexbin(crime['Longitude'],crime['Latitude'],bins='log',cmap=plt.cm.YlOrRd_r)
