# %%
import pandas as pd
from apriori import *
econ =pd.read_csv('./Downloads/SV151_2013_Principles_of_Economics.csv', header=None, names=['major','class','year','term'])

# %%
econ.head()
# Out:
#   major class year    term
# 0   CPE    JR   Y3  Winter
# 1    EE    JR   Y3  Winter
# 2    ME    SR   Y4  Winter
# 3    ME    SO   Y2  Winter
# 4   CHE    JR   Y3  Winter

# %%
econ.values
# Out:
# array([['CPE', 'JR', 'Y3', 'Winter'],
#        ['EE', 'JR', 'Y3', 'Winter'],
#        ['ME', 'SR', 'Y4', 'Winter'],
#        ['ME', 'SO', 'Y2', 'Winter'],
#        ['CHE', 'JR', 'Y3', 'Winter'],
#        ['ME', 'SO', 'Y2', 'Winter'],
#        ['MA', 'SO', 'Y2', 'Winter'],
#        ['CPE', 'SO', 'Y2', 'Winter'],
#        ['ME', 'JR', 'Y3', 'Winter'],
#        ['SE', 'JR', 'Y3', 'Winter'],
#        ['ME', 'SO', 'Y1', 'Winter'],
#        ['EE', 'JR', 'Y3', 'Winter'],
#        ['EE', 'SO', 'Y2', 'Winter'],
#        ['EE', 'SO', 'Y2', 'Winter'],
#        ['CHE', 'SO', 'Y2', 'Winter'],
#        ['CHE', 'FR', 'Y1', 'Winter'],
#        ['ME', 'JR', 'Y3', 'Winter'],
#        ['CHE', 'SR', 'Y4', 'Winter'],
#        ['SE/CS', 'SO', 'Y2', 'Winter'],
#        ['CS', 'SO', 'Y2', 'Winter'],
#        ['ME', 'SO', 'Y3', 'Winter'],
#        ['CHE', 'SR', 'Y4', 'Winter'],
#        ['PH', 'SO', 'Y2', 'Winter'],
#        ['EE', 'JR', 'Y3', 'Winter'],
#        ['EP', 'JR', 'Y2', 'Winter'],
# ...

# %%
itemsets, rules = runApriori(econ.values,0.1,0.9)

# %%
itemsets
# Out:
# [(('Spring',), 0.2943722943722944),
#  (('SO',), 0.46320346320346323),
#  (('Winter',), 0.3939393939393939),
#  (('ME',), 0.2943722943722944),
#  (('EE',), 0.11688311688311688),
#  (('JR',), 0.19480519480519481),
#  (('Fall',), 0.3116883116883117),
#  (('CHE',), 0.14285714285714285),
#  (('Y3',), 0.18181818181818182),
#  (('Y4',), 0.12121212121212122),
#  (('FR',), 0.1774891774891775),
#  (('Y2',), 0.4155844155844156),
#  (('Y1',), 0.24242424242424243),
#  (('SR',), 0.1645021645021645),
#  (('ME', 'SO'), 0.15151515151515152),
#  (('Y1', 'Winter'), 0.12121212121212122),
#  (('Y2', 'Winter'), 0.18181818181818182),
#  (('ME', 'Y2'), 0.15584415584415584),
#  (('Y2', 'SO'), 0.3593073593073593),
#  (('Y2', 'Fall'), 0.12987012987012986),
#  (('ME', 'Winter'), 0.11255411255411256),
#  (('SO', 'Winter'), 0.18181818181818182),
#  (('Spring', 'SO'), 0.1341991341991342),
#  (('SO', 'Fall'), 0.1471861471861472),
#  (('Spring', 'Y2'), 0.1038961038961039),
#  (('ME', 'Fall'), 0.11255411255411256),
# ...

# %%
rules
# Out:
# [((('Y4',), ('SR',)), 0.9642857142857142),
#  ((('FR',), ('Y1',)), 0.9268292682926829),
#  ((('Y2', 'Fall'), ('SO',)), 0.9333333333333335)]
