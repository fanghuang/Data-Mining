# %%
import pandas as pd
import matplotlib.pyplot as plt
Ti = pd.read_csv('./Downloads/Titanic.csv')
from sklearn import preprocessing
from sklearn import tree
le  = preprocessing.LabelEncoder()

# %%
cTi=Ti.set_index(['Sex','Age','Class','Survived'])

# %%
cTi.unstack()
# Out:
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#                     Unnamed: 0       Freq
# Survived                    No  Yes    No  Yes
# Sex    Age   Class
# Female Adult 1st            13   29     4  140
#              2nd            14   30    13   80
#              3rd            15   31    89   76
#              Crew           16   32     3   20
#        Child 1st             5   21     0    1
#              2nd             6   22     0   13
#              3rd             7   23    17   14
#              Crew            8   24     0    0
# Male   Adult 1st             9   25   118   57
#              2nd            10   26   154   14
#              3rd            11   27   387   75
#              Crew           12   28   670  192
#        Child 1st             1   17     0    5
#              2nd             2   18     0   11
#              3rd             3   19    35   13
#              Crew            4   20     0    0

# %%
t1=cTi.sum(axis=0,level=[0,1])

# %%
t1
# Out:
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#               Unnamed: 0  Freq
# Sex    Age
# Female Adult         180   425
#        Child         116    45
# Male   Adult         148  1667
#        Child          84    64

# %%
t2=cTi.sum(axis=0,level=[0,2])
t2
# Out:
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#               Unnamed: 0  Freq
# Sex    Class
# Female 1st            68   145
#        2nd            72   106
#        3rd            76   196
#        Crew           80    23
# Male   1st            52   180
#        2nd            56   179
#        3rd            60   510
#        Crew           64   862

# %%
s1=t1.sum(axis=1)
s1
# Out:
# Sex     Age
# Female  Adult     605
#         Child     161
# Male    Adult    1815
#         Child     148
# dtype: int64

# %%
s2=t2.sum(axis=1)
s2
# Out:
# Sex     Class
# Female  1st      213
#         2nd      178
#         3rd      272
#         Crew     103
# Male    1st      232
#         2nd      235
#         3rd      570
#         Crew     926
# dtype: int64

# %%
t1.divide(1.0*s1,axis=0,level=0)
# Out:
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#               Unnamed: 0      Freq
# Sex    Age
# Female Adult    0.297521  0.702479
#        Child    0.720497  0.279503
# Male   Adult    0.081543  0.918457
#        Child    0.567568  0.432432

# %%
t2.divide(1.0*s2,axis=0,level=0)
# Out:
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /home/huangf/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#               Unnamed: 0      Freq
# Sex    Class
# Female 1st      0.319249  0.680751
#        2nd      0.404494  0.595506
#        3rd      0.279412  0.720588
#        Crew     0.776699  0.223301
# Male   1st      0.224138  0.775862
#        2nd      0.238298  0.761702
#        3rd      0.105263  0.894737
#        Crew     0.069114  0.930886
